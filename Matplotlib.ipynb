# %% [markdown]
# <a href="https://colab.research.google.com/github/PawanKrGunjan/Python-Library/blob/main/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Om Gan Ganpate Namah**

# %%
from matplotlib import pylab

# %%
pylab.__version__
# Out:
# '1.19.5'

# %%
#use NumPy to generate random data

import numpy as np

x=np.linspace(0,10,25)
y=x*x+2

# %%
print(x)
# Out:
# [ 0.          0.41666667  0.83333333  1.25        1.66666667  2.08333333
#   2.5         2.91666667  3.33333333  3.75        4.16666667  4.58333333
#   5.          5.41666667  5.83333333  6.25        6.66666667  7.08333333
#   7.5         7.91666667  8.33333333  8.75        9.16666667  9.58333333
#  10.        ]

# %%
print(y)
# Out:
# [  2.           2.17361111   2.69444444   3.5625       4.77777778
#    6.34027778   8.25        10.50694444  13.11111111  16.0625
#   19.36111111  23.00694444  27.          31.34027778  36.02777778
#   41.0625      46.44444444  52.17361111  58.25        64.67361111
#   71.44444444  78.5625      86.02777778  93.84027778 102.        ]

# %%
print(np.array([x,y]).reshape(25,2).reshape(2,25))
# Out:
# [[  0.           0.41666667   0.83333333   1.25         1.66666667
#     2.08333333   2.5          2.91666667   3.33333333   3.75
#     4.16666667   4.58333333   5.           5.41666667   5.83333333
#     6.25         6.66666667   7.08333333   7.5          7.91666667
#     8.33333333   8.75         9.16666667   9.58333333  10.        ]
#  [  2.           2.17361111   2.69444444   3.5625       4.77777778
#     6.34027778   8.25        10.50694444  13.11111111  16.0625
#    19.36111111  23.00694444  27.          31.34027778  36.02777778
#    41.0625      46.44444444  52.17361111  58.25        64.67361111
#    71.44444444  78.5625      86.02777778  93.84027778 102.        ]]

# %%
"""It takes only one command to draw"""
pylab.plot(x,y,'g') #'g' stands for green

# %% [markdown]
# **Drawing a subgraph**

# %%
pylab.subplot(1,2,1) # The content of the brackets represent (rows, columns, indexes)
pylab.plot(x,y, 'r--') # The third parameter here determines color and line style
pylab.subplot(1,2,2) #index= location of graph (same index means overlaps)
pylab.plot(y,x,'g-*')

# %%
pylab.subplot(1,2,1) # The content of the brackets represent (rows, columns, indexes)
pylab.plot(x,y, 'r--') # The third parameter here determines color and line style
pylab.subplot(2,2,2) #index= location of graph (same index means overlaps)
pylab.plot(y,x,'g-*')

# %%
pylab.subplot(1,1,1) # The content of the brackets represent (rows, columns, indexes)
pylab.plot(x,y, 'r--') # The third parameter here determines color and line style
pylab.subplot(1,1,1) #index= location of graph (same index means overlaps)
pylab.plot(y,x,'g-*')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#pylab.subplot(1,1,1) # The content of the brackets represent (rows, columns, indexes)
pylab.plot(x,y, 'r--') # The third parameter here determines color and line style
#pylab.subplot(1,1,1) #index= location of graph (same index means overlaps)
pylab.plot(y,x,'g-*')

# %% [markdown]
# # Operator Description
# fig.add_axes() =initializes subplot a =fig.add_subplot(222)

# %% [markdown]
# fig.b=plt.subplot(nrows=3,nclos=2)=Adds subplot

# %% [markdown]
# ax = plt.subplots(2,2) = Creates subplot

# %%
from matplotlib import pyplot as plt

# %%
fig = plt.figure()
axis = fig.add_axes([0.5, 0.1, 0.8, 0.8]) #Control the left, up, width, height of the canvas (from 0 to 1)
axis.plot(x, y, 'r')

# %%
# Subgraph
fig, axis = plt.subplots(nrows = 1, ncols =2)  #submap is of 1 row, 2 columns
for ax in axis:
    ax.plot(x,y, 'g')

# %%
# Subgraph
fig, axis = plt.subplots(nrows = 1, ncols =3)  #submap is of 1 row, 2 columns
for ax in axis:
    ax.plot(x,y, 'r')

# %%
# Subgraph
fig, axis = plt.subplots(nrows = 2, ncols =1)  #submap is of 1 row, 2 columns
for ax in axis:
    ax.plot(x,y, 'g')

# %% [markdown]
# **we can also draw a picture, or graph, inside another graph**

# %%
fig = plt.figure()

#Control the [left, up, width, height] of the canvas (from 0 to 1)

axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # big axes
axes2 = fig.add_axes([0.2, 0.5, 0.4, 0.3]) # small canvas

axes1.plot(x,y, 'r')
axes2.plot(y,x, 'g')

# %%
fig = plt.figure()

#Control the [left, up, width,  height] of the canvas (from 0 to 1)

axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # big axes
axes2 = fig.add_axes([0.2, 0.5, 0.4, 0.5]) # small canvas

axes1.plot(x,y, 'r')
axes2.plot(y,x, 'g')

# %%
fig = plt.figure()

#Control the [left, up, width,  height] of the canvas (from 0 to 1)

axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # big axes
axes2 = fig.add_axes([0.15, 0.35, 0.4, 0.5]) # small canvas

axes1.plot(x,y, 'r')
axes2.plot(y,x, 'g')

# %%
fig = plt.figure(figsize=(16,9), dpi=300) #New graphic object
fig.add_subplot()
plt.plot(x,y,'r')

# %%
fig = plt.figure(figsize=(16,9), dpi=50) #New graphic object
#fig.add_subplot()
plt.plot(x,y,'r')

# %%
fig = plt.figure() #New graphic object
plt.plot(x,y,'r')

# %%
fig, axes = plt.subplots(dpi=300)
axes.plot(x,y,'r')

# %%
fig, axes = plt.subplots(figsize = (16,9), dpi=100)

axes.set_xlabel("x")
axes.set_ylabel("y")

axes.set_title("Graph title")

axes.plot(x,y,'r')

# %%
fig, axes = plt.subplots(dpi=300)

axes.set_xlabel("x")
axes.set_ylabel("y")

axes.set_title("Graph title")

axes.plot(x,x**3,'r')
axes.plot(x,x**2,'g')

# %%
ax.legend(['label1','label2'])

fig, axes = plt.subplots( dpi=200)

axes.set_xlabel("x")
axes.set_ylabel("y")

axes.set_title("Graph title")

axes.plot(x,x**3,'r')
axes.plot(x,x**2,'g')

axes.legend(["y=x**3","y=x**2"],loc=2)

# %%
ax.legend(['label1','label2'])

fig, axes = plt.subplots( dpi=100)

axes.set_xlabel("x")
axes.set_ylabel("y")

axes.set_title("Graph title")

axes.plot(x,x**3,'r')
axes.plot(x,x**2,'g')

axes.legend(["y=x**3","y=x**2"],loc=6)

# %% [markdown]
# **In Matplotlib, we can set other properties such as line color, tranparancy, and more.**

# %%
fig, axes = plt.subplots(dpi=150)
axes.plot(x,x+1, color='red')
axes.plot(x,x+2, color='#1155dd')
axes.plot(x,x+3, color='#15cc55')

# %%
fig, axes = plt.subplots(dpi=150)
axes.plot(x,x**2, color='red', alpha=.3)
axes.plot(x,x+2, color='#1155dd', alpha=.3)
axes.plot(x,x+3, color='#15cc55', alpha=.3)

# %%
fig,ax = plt.subplots(dpi=100)

#Line width

ax.plot(x, x+1, color='blue', linewidth=0.25)
ax.plot(x, x+2, color='blue', linewidth=1)
ax.plot(x, x+3, color='blue', linewidth=1.5)
ax.plot(x, x+4, color='blue', linewidth=2)

# %%
fig,ax = plt.subplots(dpi=100)

#Line width

ax.plot(x, x+1, color='blue', lw=0.5)
ax.plot(x, x+2, color='blue', lw=1)
ax.plot(x, x+3, color='blue', lw=1.5)
ax.plot(x, x+4, color='blue', lw=2)

# %%
fig,ax = plt.subplots(dpi=100)

#Line width

ax.plot(x, x+1, color='blue', lw=2, linestyle='-')
ax.plot(x, x+2, color='blue', lw=2, linestyle='-.')
ax.plot(x, x+3, color='blue', lw=2, linestyle=':')

# %%
fig,ax = plt.subplots(dpi=200)

#Line width

ax.plot(x, x+1, color='blue', lw=2, linestyle='-')
ax.plot(x, x+2, color='blue', lw=2, linestyle='-.')
ax.plot(x, x+3, color='blue', lw=2, linestyle=':')

line, = ax.plot(x, x+5, color ='black', lw=1.50)
line.set_dashes([5, 10, 15, 10])
line, = ax.plot(x, x+6, color ='black', lw=1.50)
line.set_dashes([5,10, 15, 3])
line, = ax.plot(x, x+7, color ='black', lw=1.50)
line.set_dashes([5, 10, 4, 10])
line, = ax.plot(x, x+8, color ='black', lw=1.50)
line.set_dashes([5, 10, 30, 30])

# %%
fig, axes = plt.subplots(dpi=100)
axes.plot(x,x+1, color='green', marker='o')
axes.plot(x,x+2, color='green', marker='+')
axes.plot(x,x+3, color='green', marker='s')
axes.plot(x,x+4, color='green', marker='1')

axes.plot(x,x+5, color='green', marker='o', markersize=5)
axes.plot(x,x+6, color='green', marker='+', markerfacecolor='red')
axes.plot(x,x+7, color='green', marker='s', markersize=8, markerfacecolor='red')
axes.plot(x,x+8, color='green', marker='1', markersize=10)

# %% [markdown]
# **Set the canvas grid and axis range**

# %%
fig, Axes = plt.subplots(1, 2, figsize=(10,5))

Axes[0].plot(x, x**2, x, x**3, lw=2)
Axes[0].grid(True)

Axes[1].plot(x, x**2, x**3, lw=2)
Axes[1].grid(True)
Axes[1].set_ylim([0,60])
Axes[1].set_xlim([2,5])
# Out:
# (2.0, 5.0)

# %% [markdown]
# # Other 2D Graphics

# %%
n = np.array([0,1,2,3,4,5])

fig, axes = plt.subplots(1,4, figsize=(16,5))

axes[0].set_title("Scatter")
axes[0].scatter(x, x + 0.25*np.random.randn(len(x)))

axes[1].set_title("Step")
axes[1].step(n, n**2, lw=2)

axes[2].set_title("Bar Graph")
axes[2].bar(n, n**2, align="center", alpha=0.8)

axes[3].set_title("Fill Between")
axes[3].fill_between(x, x**2, x**3, color="red", alpha=0.5)

# %%
fig, axes = plt.subplots( figsize=(12,5))
axes.set_title("Bar Graph")
axes.bar(n, n**3, align="center", alpha=0.5, color="green")
# Out:
# <BarContainer object of 6 artists>

# %%
fig = plt.figure(figsize=(6,6))
ax= fig.add_axes([0.0, 0.0, .6, .6])

# %%
"""Draw a radar chart"""
fig = plt.figure(figsize=(6,6))
ax= fig.add_axes([0.0, 0.0, 1, 1], polar= True)

# %%
"""Draw a radar chart"""
fig = plt.figure(figsize=(6,6))
ax= fig.add_axes([0.0, 0.0, 1, 1], polar= True)
t= np.linspace(0, 6*np.pi, 100)                  #6*180 : 3 turns
ax.plot(t, t*3, color='red', lw=2)

# %% [markdown]
# **Histogram**

# %%
n= np.random.randn(100000)
fig, axes = plt.subplots(1,2, figsize=(12,4))
axes[0].set_title("Default histogram")
axes[0].hist(n)

axes[1].set_title("histogram")
axes[1].hist(n, cumulative = False, bins = 10)
# Out:
# (array([2.5000e+01, 4.4600e+02, 3.5820e+03, 1.5037e+04, 3.0475e+04,
#         3.0723e+04, 1.5341e+04, 3.8830e+03, 4.5000e+02, 3.8000e+01]),
#  array([-4.32907603, -3.4652976 , -2.60151917, -1.73774074, -0.87396231,
#         -0.01018388,  0.85359455,  1.71737299,  2.58115142,  3.44492985,
#          4.30870828]),
#  <a list of 10 Patch objects>)

# %%
fig, axes = plt.subplots(1,2, figsize=(12,4))
axes[0].set_title("Default histogram")
axes[0].hist(n,  bins = 50)

axes[1].set_title("Cumulative detailed histogram")
axes[1].hist(n, cumulative = True, bins = 50)
# Out:
# (array([4.0000e+00, 5.0000e+00, 9.0000e+00, 1.4000e+01, 2.5000e+01,
#         4.4000e+01, 8.6000e+01, 1.4700e+02, 2.6600e+02, 4.7100e+02,
#         7.6100e+02, 1.1950e+03, 1.8260e+03, 2.7670e+03, 4.0530e+03,
#         5.8610e+03, 8.2210e+03, 1.1146e+04, 1.4766e+04, 1.9090e+04,
#         2.4198e+04, 2.9942e+04, 3.6104e+04, 4.2818e+04, 4.9565e+04,
#         5.6281e+04, 6.2976e+04, 6.9297e+04, 7.5113e+04, 8.0288e+04,
#         8.4665e+04, 8.8378e+04, 9.1397e+04, 9.3768e+04, 9.5629e+04,
#         9.7039e+04, 9.8010e+04, 9.8718e+04, 9.9185e+04, 9.9512e+04,
#         9.9694e+04, 9.9821e+04, 9.9898e+04, 9.9937e+04, 9.9962e+04,
#         9.9980e+04, 9.9987e+04, 9.9994e+04, 9.9998e+04, 1.0000e+05]),
#  array([-4.32907603, -4.15632035, -3.98356466, -3.81080897, -3.63805329,
#         -3.4652976 , -3.29254192, -3.11978623, -2.94703054, -2.77427486,
#         -2.60151917, -2.42876348, -2.2560078 , -2.08325211, -1.91049643,
# ...

# %% [markdown]
# **Draw contour image**

# %%
delta = 0.025

# %%
x = np.arange(-3.0, 3.0, delta)
y = np.arange(-2.0, 2.0, delta)
print(x)
print(y)
# Out:
# [-3.0000000e+00 -2.9750000e+00 -2.9500000e+00 -2.9250000e+00
#  -2.9000000e+00 -2.8750000e+00 -2.8500000e+00 -2.8250000e+00
#  -2.8000000e+00 -2.7750000e+00 -2.7500000e+00 -2.7250000e+00
#  -2.7000000e+00 -2.6750000e+00 -2.6500000e+00 -2.6250000e+00
#  -2.6000000e+00 -2.5750000e+00 -2.5500000e+00 -2.5250000e+00
#  -2.5000000e+00 -2.4750000e+00 -2.4500000e+00 -2.4250000e+00
#  -2.4000000e+00 -2.3750000e+00 -2.3500000e+00 -2.3250000e+00
#  -2.3000000e+00 -2.2750000e+00 -2.2500000e+00 -2.2250000e+00
#  -2.2000000e+00 -2.1750000e+00 -2.1500000e+00 -2.1250000e+00
#  -2.1000000e+00 -2.0750000e+00 -2.0500000e+00 -2.0250000e+00
#  -2.0000000e+00 -1.9750000e+00 -1.9500000e+00 -1.9250000e+00
#  -1.9000000e+00 -1.8750000e+00 -1.8500000e+00 -1.8250000e+00
#  -1.8000000e+00 -1.7750000e+00 -1.7500000e+00 -1.7250000e+00
#  -1.7000000e+00 -1.6750000e+00 -1.6500000e+00 -1.6250000e+00
#  -1.6000000e+00 -1.5750000e+00 -1.5500000e+00 -1.5250000e+00
# ...

# %%
x, y = np.meshgrid(x,y)
x,y
# Out:
# (array([[-3.   , -2.975, -2.95 , ...,  2.925,  2.95 ,  2.975],
#         [-3.   , -2.975, -2.95 , ...,  2.925,  2.95 ,  2.975],
#         [-3.   , -2.975, -2.95 , ...,  2.925,  2.95 ,  2.975],
#         ...,
#         [-3.   , -2.975, -2.95 , ...,  2.925,  2.95 ,  2.975],
#         [-3.   , -2.975, -2.95 , ...,  2.925,  2.95 ,  2.975],
#         [-3.   , -2.975, -2.95 , ...,  2.925,  2.95 ,  2.975]]),
#  array([[-2.   , -2.   , -2.   , ..., -2.   , -2.   , -2.   ],
#         [-1.975, -1.975, -1.975, ..., -1.975, -1.975, -1.975],
#         [-1.95 , -1.95 , -1.95 , ..., -1.95 , -1.95 , -1.95 ],
#         ...,
#         [ 1.925,  1.925,  1.925, ...,  1.925,  1.925,  1.925],
#         [ 1.95 ,  1.95 ,  1.95 , ...,  1.95 ,  1.95 ,  1.95 ],
#         [ 1.975,  1.975,  1.975, ...,  1.975,  1.975,  1.975]]))

# %%
z1 = np.exp(-x**2-y**2)
z2 = np.exp(-(x-1)**2-(y-1)**2)
z = (z1-z2)*2
z
# Out:
# array([[ 4.52063104e-06,  5.24894067e-06,  6.08697321e-06, ...,
#          9.82013796e-07,  5.79256020e-07,  2.55995511e-07],
#        [ 4.99294681e-06,  5.79735018e-06,  6.72294028e-06, ...,
#          7.40995503e-07,  3.27884007e-07,  2.57498016e-19],
#        [ 5.50772112e-06,  6.39505861e-06,  7.41607717e-06, ...,
#          4.18911596e-07,  3.15943289e-19, -3.27884007e-07],
#        ...,
#        [ 5.97236348e-06,  6.92886625e-06,  8.02817162e-06, ...,
#         -2.08885159e-02, -1.89602868e-02, -1.71885358e-02],
#        [ 5.41648023e-06,  6.28368636e-06,  7.28030161e-06, ...,
#         -1.99324015e-02, -1.80924123e-02, -1.64017434e-02],
#        [ 4.90598951e-06,  5.69120666e-06,  6.59353913e-06, ...,
#         -1.89962699e-02, -1.72426787e-02, -1.56313990e-02]])

# %%
fig, ax = plt.subplots()
CS = ax.contour(x, y, z)
ax.clabel(CS, inline=1, fontsize=10)
ax.set_title('Contour map')
# Out:
# Text(0.5, 1.0, 'Contour map')

# %% [markdown]
# # Heatmap

# %% [markdown]
# **Draw a 3D surface image**

# %%
from mpl_toolkits.mplot3d.axes3d import Axes3D

# %%
fig = plt.figure(figsize=(14,6))
# Specify the 3D graphics to draw, with projection = "3d"
ax = fig.add_subplot(1, 2, 1, projection='3d')

X,Y,Z=x,y,z

ax.plot_surface(X, Y, Z, rstride=4,cstride=4, linewidth=0)

# %%
#import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator
#import numpy as np

# %%
# Make data.
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)
Z
# Out:
# array([[ 0.70886129,  0.57562789,  0.42921793, ...,  0.27541086,
#          0.42921793,  0.57562789],
#        [ 0.57562789,  0.4208019 ,  0.2570234 , ...,  0.09046523,
#          0.2570234 ,  0.4208019 ],
#        [ 0.42921793,  0.2570234 ,  0.08068791, ..., -0.09334004,
#          0.08068791,  0.2570234 ],
#        ...,
#        [ 0.27541086,  0.09046523, -0.09334004, ..., -0.26940744,
#         -0.09334004,  0.09046523],
#        [ 0.42921793,  0.2570234 ,  0.08068791, ..., -0.09334004,
#          0.08068791,  0.2570234 ],
#        [ 0.57562789,  0.4208019 ,  0.2570234 , ...,  0.09046523,
#          0.2570234 ,  0.4208019 ]])

# %%
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
import matplotlib.ticker as tick
# Plot the surface.
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)
# Customize the z axis.
ax.set_zlim(-1.01, 1.01)
ax.zaxis.set_major_locator(LinearLocator(5))
# A StrMethodFormatter is used automatically
ax.zaxis.set_major_formatter(tick.FormatStrFormatter('{x:.02f}'))


# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=10)

plt.show()

# %% [markdown]
# # Piechart

# %%
import matplotlib.pyplot as plt
# Data to plot
languages='Python', 'Java','PHP', 'JavaScript', 'c#', 'C++'
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
colors=['#1f77b4','#ff7f0e','#2ca02c','#d62728','#9467bd', '#8c564b']

# %%
#explode 1st slice
#explode 1st slice
explode = (0.1, 0, 0,0, 0,0)
plt.pie(popularity, explode= explode, labels= languages, colors = colors, autopct='%1.1f%%',shadow=True, startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x7ff6e0c075d0>,
# ...
#  [Text(-0.9981321564304079, 0.6661322678714671, 'Python'),
#   Text(-0.4265661418401122, -1.0139237282141302, 'Java'),
#   Text(0.7656789278855427, -0.7897694469856669, 'PHP'),
#   Text(1.0981806733680344, -0.06323929665114078, 'JavaScript'),
#   Text(0.8841620379545417, 0.6544138527262939, 'c#'),
#   Text(0.321350164763084, 1.0520142924916651, 'C++')],
#  [Text(-0.5822437579177379, 0.38857715625835576, '31.3%'),
#   Text(-0.23267244100369755, -0.5530493062986164, '24.8%'),
#   Text(0.4176430515739324, -0.4307833347194546, '12.4%'),
#   Text(0.5990076400189277, -0.034494161809713146, '11.3%'),
#   Text(0.48227020252065905, 0.3569530105779785, '10.8%'),
#   Text(0.17528190805259122, 0.5738259777227264, '9.4%')])
